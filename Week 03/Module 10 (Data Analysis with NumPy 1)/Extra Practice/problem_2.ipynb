# %%
import numpy as np

lap_times = [248.3, 251.7, 245.9, 260.4, 255.1, 242.8, 263.0, 258.6, 249.2, 254.7,
 262.3, 271.9, 268.4, 257.0, 246.5, 273.8, 265.1, 259.4, 252.0, 270.6,
 281.4, 276.2, 269.9, 263.7, 258.1, 284.3, 279.5, 272.8, 267.4, 275.0]

# %%
arr = np.array(lap_times)

print(f"shape: {arr.shape}")
print(f"size: {arr.size}")
print(f"data type: {arr.dtype}")

lab_time_in_minute = arr/60

print(lab_time_in_minute)
# Out:
# shape: (30,)
# size: 30
# data type: float64
# [4.13833333 4.195      4.09833333 4.34       4.25166667 4.04666667
#  4.38333333 4.31       4.15333333 4.245      4.37166667 4.53166667
#  4.47333333 4.28333333 4.10833333 4.56333333 4.41833333 4.32333333
#  4.2        4.51       4.69       4.60333333 4.49833333 4.395
#  4.30166667 4.73833333 4.65833333 4.54666667 4.45666667 4.58333333]
