# %%
import numpy as np

cel = [12.4, 15.0, 18.7, 21.3, 19.8, 16.1, 13.5]

# %%
fah = np.array(cel)
fah = (fah*1.8)+32

for i in np.nditer(fah):
    print(i)
# Out:
# 54.32
# 59.0
# 65.66
# 70.34
# 67.64
# 60.980000000000004
# 56.3
