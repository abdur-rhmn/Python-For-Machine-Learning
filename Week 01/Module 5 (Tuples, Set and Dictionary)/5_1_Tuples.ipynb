# %%
tup = (10,20,30)

tup1 = (10)

tup2 = (10,)

tup3 = tuple([10])

lst = [22,11,55]

tup4 = tuple(lst)

print(type(tup), tup)
print(type(tup1), tup1)
print(type(tup2), tup2)
print(type(tup3), tup3)
print(tup4)
# Out:
# <class 'tuple'> (10, 20, 30)
# <class 'int'> 10
# <class 'tuple'> (10,)
# <class 'tuple'> (10,)
# (22, 11, 55)

# %%
# access

tup = (10, 20, 10.4, "str", True)

print(tup[3])

new_tup = tup[0:3]

print(new_tup)
# Out:
# str
# (10, 20, 10.4)
