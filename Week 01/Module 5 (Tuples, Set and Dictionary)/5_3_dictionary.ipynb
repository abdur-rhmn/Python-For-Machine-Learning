# %%
dic = {}

print(type(dic))
# Out:
# <class 'dict'>

# %%
# dic[immutable:mutable]
dic = {"name": "Abdur Rahman", "roll": 758473, "class": 12, "marks": [98,88,97,80]}

print(dic)
# Out:
# {'name': 'Abdur Rahman', 'roll': 758473, 'class': 12, 'marks': [98, 88, 97, 80]}

# %%
# access

print(dic["name"])

print(dic.get("marks"))
# Out:
# Abdur Rahman
# [98, 88, 97, 80]

# %%
dic["roll"] = 758476

print(dic["roll"])

print(dic["class"])
# Out:
# 758476
# 10

# %%
dic = {"name": "Abdur Rahman", "roll": 758473, "class": 12, "marks": [98,88,97,80]}

print(dic.get("math_marks"))
print(dic.get("math_marks", 0))
# Out:
# None
# 0

# %%
# insertion

dic["age"] = 22

print(dic)
# Out:
# {'name': 'Abdur Rahman', 'roll': 758473, 'class': 12, 'marks': [98, 88, 97, 80], 'age': 22}

# %%
dic = {"name": "Abdur Rahman", "age": 22, "roll": 758473, "class": 12, "marks": [98,88,97,80]}

dic.update({"math_marks" : 90})

print(dic)
# Out:
# {'name': 'Abdur Rahman', 'age': 22, 'roll': 758473, 'class': 12, 'marks': [98, 88, 97, 80], 'math_marks': 90}

# %%
# deleting
del dic["age"]

print(dic)
# Out:
# {'name': 'Abdur Rahman', 'roll': 758473, 'class': 12, 'marks': [98, 88, 97, 80], 'math_marks': 90}

# %%
# copy dic

dic_2 = dic.copy()

print(dic_2)
# Out:
# {'name': 'Abdur Rahman', 'roll': 758473, 'class': 12, 'marks': [98, 88, 97, 80], 'math_marks': 90}

# %% [markdown]
# ## realtime access

# %%
dic = {"name": "Abdur Rahman", "roll": 758473, "class": 12, "marks": [98,88,97,80]}

keys = dic.keys()

values = dic.values()

items = dic.items()

dic["math_mark"] = 90

print(keys)

print(values)

print(items)
# Out:
# dict_keys(['name', 'roll', 'class', 'marks', 'math_mark'])
# dict_values(['Abdur Rahman', 758473, 12, [98, 88, 97, 80], 90])
# dict_items([('name', 'Abdur Rahman'), ('roll', 758473), ('class', 12), ('marks', [98, 88, 97, 80]), ('math_mark', 90)])

# %% [markdown]
# ## Iteration

# %%
for key, value in dic.items():
    print(key,value)
# Out:
# name Abdur Rahman
# roll 758473
# class 12
# marks [98, 88, 97, 80]
# math_mark 90

# %% [markdown]
# ## 5.6 Dictionary Comprehension

# %%
square = {x : x**2 for x in range(10) if x%2 == 0}

print(square)
# Out:
# {0: 0, 2: 4, 4: 16, 6: 36, 8: 64}

# %%
co_ordinate = [(10,10.4),(5,6),(23,54)]
location = ["Dhaka", "chottogram", "sylhet"]

exect_loc = {co_or : loc for co_or, loc in zip(co_ordinate, location)}

print(exect_loc)
# Out:
# {(10, 10.4): 'Dhaka', (5, 6): 'chottogram', (23, 54): 'sylhet'}

# %% [markdown]
# ## 1. Given a list of numbers, make a list with unique values.

# %%
lst = [10 , 20 , 10 , 30 , 30 , 50 , 30 , 10 , 20 , 10 , 10 ]

unique_val = set(lst)

print(unique_val)
# Out:
# {10, 20, 50, 30}

# %% [markdown]
# ## 2. Given a string , print the frequency of the words

# %%
string = """data science machine learning data analysis machine 
learning statistics data models data training data validation features
features labels preprocessing data augmentation models data optimization 
gradient descent neural networks data tensors matrices visualization 
exploration pandas numpy matplotlib seaborn scikitlearn tensorflow pytorch 
deployment inference production monitoring reproducibility experiments results 
metrics accuracy precision recall f1 cross validation data machine
"""

words = string.split()

count = {}

for word in words:
    count[word] = count.get(word, 0) + 1

for k,v in count.items():
    print(k,v)
# Out:
# data 9
# science 1
# machine 3
# learning 2
# analysis 1
# statistics 1
# models 2
# training 1
# validation 2
# features 2
# labels 1
# preprocessing 1
# augmentation 1
# optimization 1
# gradient 1
# descent 1
# neural 1
# networks 1
# tensors 1
# matrices 1
# visualization 1
# exploration 1
# pandas 1
# numpy 1
# matplotlib 1
# seaborn 1
# scikitlearn 1
# tensorflow 1
# pytorch 1
# deployment 1
# inference 1
# production 1
# monitoring 1
# reproducibility 1
# experiments 1
# results 1
# metrics 1
# accuracy 1
# precision 1
# recall 1
# f1 1
# cross 1
