# %%
name = input("Enter your name: ")

print(name)
# Out:
# abdur rahman

# %%
age = input("Enter your age: ")

print(age, type(age))
# Out:
# 55 <class 'str'>

# %%
age = input("Enter your Age: ")

age = int(age)

# age = int(input("Enter your Age: "))

print(age, type(age))
# Out:
# 66 <class 'int'>
