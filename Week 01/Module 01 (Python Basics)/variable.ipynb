# %%
phone_number = 26496356

print(phone_number)

# %%
name = "Abdur Rahman"
age = 22
hight =  5.6
is_passed = True

print(name, age, hight, is_passed)
print(type(name), type(age), type(hight), type(is_passed))
