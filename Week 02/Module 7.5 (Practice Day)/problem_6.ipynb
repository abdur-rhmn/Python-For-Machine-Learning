# %%
try:
  with open("./sample_data/story.txt", 'r') as file:
    lines = file.readlines()
    print(f"total lines: {len(lines)}")
    print(lines)
except Exception as e:
    print(e)
finally:
  print("Operation Done!")
# Out:
# total lines: 3
# ['[2025-11-03 14:22] System rebooted successfully.\n', '[2025-11-03 14:24] User request initiated: File integrity check.\n', '[2025-11-03 14:25] Warning: Missing index reference.']
# Operation Done!
