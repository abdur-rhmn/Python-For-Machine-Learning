# %%
# lambda parameter : expression condition

add = lambda x, y : x+y

print(add(10,20))
# Out:
# 30

# %%
is_even = lambda x : x%2 == 0

print(is_even(11))
# Out:
# False

# %%
ev_sq = lambda x : x**2 if x%2 == 0 else x


print(ev_sq(10))

print(ev_sq(9))
# Out:
# 100
# 9
